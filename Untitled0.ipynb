# %% [markdown]
# <a href="https://colab.research.google.com/github/eliza-souza/eliza-souza/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd


# Load dataset
from google.colab import files
uploaded = files.upload()  # Upload the dataset file (e.g., winequality-red.csv)
df = pd.read_csv('winequality-red.csv', delimiter=';')  # Adjust delimiter if needed

# Display first few rows and summary info
df.head(), df.info()
# Out:
#      <input type="file" id="files-b0e852cd-fb50-454c-8b42-cb33e21d676f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b0e852cd-fb50-454c-8b42-cb33e21d676f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 2. Adding a new categorical variable 'alcohol_level' by binning 'alcohol' into categories
df['alcohol_level'] = pd.cut(df['alcohol'], bins=[0, 10, 12, 15], labels=['Low', 'Medium', 'High'])

# Verifying the new categorical variable
df[['alcohol', 'alcohol_level']].head()
# Out:
#    alcohol alcohol_level
# 0      9.4           Low
# 1      9.8           Low
# 2      9.8           Low
# 3      9.8           Low
# 4      9.4           Low

# %%
# 3. Descriptive statistics for continuous variables
continuous_stats = df.describe()
print("\nDescriptive Statistics for Continuous Variables:\n", continuous_stats)
# Out:
# Descriptive Statistics for Continuous Variables:
#         fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# Frequency counts for the categorical variable 'quality'
quality_counts = df['quality'].value_counts()
print("\nFrequency Counts for 'Quality':\n", quality_counts)
# Out:
# Frequency Counts for 'Quality':
#  quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
# Histograms for continuous variables
sns.set(style="whitegrid")
for column in df.columns[:-1]:  # Excluding 'quality'
    plt.figure()
    sns.histplot(df[column], kde=True)
    plt.title(f"Histogram of {column}")
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.show()

# %%
# Bar plot for 'quality' variable
plt.figure()
sns.countplot(x='quality', data=df)
plt.title("Quality Rating Count")
plt.xlabel("Quality")
plt.ylabel("Frequency")
plt.show()

# %%
# Box plots to analyze relationships between quality and continuous variables
for column in df.columns[:-1]:  # Excluding 'quality'
    plt.figure()
    sns.boxplot(x='quality', y=column, data=df)
    plt.title(f"Box Plot of {column} by Quality Rating")
    plt.xlabel("Quality")
    plt.ylabel(column)
    plt.show()

# %%
# Correlation matrix heatmap (excluding non-numeric columns like 'alcohol_level')
plt.figure(figsize=(10, 8))
sns.heatmap(df.select_dtypes(include=[np.number]).corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix of Wine Quality Dataset")
plt.show()
